# %% [markdown]
# # Crossover Plots

# %% [markdown]
# Code from Zac Bush, displays SNPs and crossover locations

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Crossovers

# %% [markdown]
# Read the frame that has crossover locations

# %%
bsp_COs = pd.read_pickle('bsp_COs_final_set.pickle.gzip', compression='gzip')

# %%
bsp_COs.head()
# Out:
#           sample chromosome     start      stop   hmm_state      chrom_id  \
# 172   BSP-OR-001          4  15669138  15672819  transition  BSP-OR-001-4
# 175   BSP-OR-001          5   2122282   2122633  transition  BSP-OR-001-5
# 791   BSP-OR-002          1  14819177  14819806  transition  BSP-OR-002-1
# 794   BSP-OR-002          2   2587074   2587324  transition  BSP-OR-002-2
# 1594  BSP-OR-003          1  12185988  12186112  transition  BSP-OR-003-1
#
#      length  marker_counts  upstream_CB4856_purity  downstream_CB4856_purity  \
# 172    3681              2                0.958271                  0.000000
# 175     351              2                0.000000                  0.828465
# 791     629              2                0.931145                  0.000000
# 794     250              2                0.000000                  0.816375
# 1594    124              2                0.000000                  0.993129
#
#       ...  10.0Mb_downstream_geno_purity  10.0Mb_upstream_state_purity  \
# 172   ...                       0.009974                      0.963222
# 175   ...                       0.250558                      0.000000
# 791   ...                       0.011019                      0.978697
# 794   ...                       0.135594                      0.000000
# 1594  ...                       0.396770                      0.000000
#
#       10.0Mb_downstream_state_purity  10.0Mb_geno_purity_diff  \
# 172                         0.000000                 0.339458
# 175                         0.882883                 0.248949
# 791                         0.000000                 0.294939
# 794                         0.787037                 0.132548
# 1594                        0.993763                 0.357180
#
#       10.0Mb_state_purity_diff  10.0Mb_state_cumulative_diff  is_CO  \
# 172                   0.963222                      0.897315      1
# 175                   0.882883                      0.729747      1
# 791                   0.978697                      0.567969      1
# 794                   0.787037                      0.811592      1
# 1594                  0.993763                      0.996652      1
#
#       CO_probability  germ_cell  is_double_CO
# 172            0.996     oocyte             0
# 175            0.666     oocyte             0
# 791            0.866     oocyte             0
# 794            0.876     oocyte             0
# 1594           1.000     oocyte             0
#
# [5 rows x 114 columns]

# %%
len(bsp_COs)
# Out:
# 1575

# %% [markdown]
# ### SNPS

# %%
bsp_SNPs = pd.read_pickle('BSP_TIGER.marker_dataframe.pickle.gzip', compression='gzip')

# %%
len(bsp_SNPs)
# Out:
# 130290510

# %%
len(bsp_SNPs.columns)
# Out:
# 11

# %%
bsp_SNPs.head(5)
# Out:
#        Sample  chromosome  position base_geno hmm_state1 hmm_state2 reference  \
# 0  BSP-OR-202           1       855   unknown         N2         N2         G
# 1  BSP-OR-202           1      1222   unknown         N2         N2         A
# 2  BSP-OR-202           1      1933   unknown         N2         N2         C
# 3  BSP-OR-202           1      3048       uN2         N2         N2         C
# 4  BSP-OR-202           1      3659        N2         N2         N2         C
#
#    ref_reads variant  var_reads      chrom_id
# 0          0       C          0  BSP-OR-202-1
# 1          0       C          0  BSP-OR-202-1
# 2          0       G          0  BSP-OR-202-1
# 3          3       G          0  BSP-OR-202-1
# 4          7       T          2  BSP-OR-202-1

# %% [markdown]
# ### Plot Function

# %%
tiger_marker_df = bsp_SNPs

# %%
def plot_single_chromosomes(chrom_id = str, plot_strip = True, strip_col=str, plot_data = True, data_cols = []):

    bases_df = tiger_marker_df[tiger_marker_df['chrom_id']==chrom_id]
    intervals_df = bsp_COs[bsp_COs['chrom_id']==chrom_id]

    palette = {'CB4856':'mediumblue', 'N2':'crimson', "het":"darkblue", "uN2":'red', "uCB4856":'mediumblue', 'unknown':"grey"}

    COs = list(intervals_df[intervals_df['is_CO']==1].start)

    print(chrom_id, COs)

    ##### plot HMM states as strip plots #####

    if plot_strip == True:
        sns.set_theme(rc={'figure.figsize':(130, 20)}, style="ticks", font_scale=5)

        sns.stripplot(data=bases_df, x="position", jitter=.3, size=20,  hue=strip_col, palette = palette)

        if len(COs) != 0:
            for co in COs:
                 plt.axvline(co, color='green', lw=7)

        plt.show()
        sns.reset_orig()


    ##### plot other data as lines #####
    if plot_data == True:
        for column in data_cols:
            print(chrom_id)
            sns.lineplot(data=intervals_df, x='stop', y=column)
            plt.show()

# %% [markdown]
# Zac's example:

# %%
plot_single_chromosomes(chrom_id = 'BSP-OR-001-4', plot_strip = True, strip_col='hmm_state1', plot_data = True, data_cols = [])
# Out:
# BSP-OR-001-4 [15669138]

# %% [markdown]
# ### Intervals

# %% [markdown]
# Another data file from Zac

# %%
intervals = pd.read_pickle('BSP_TIGER.intervals_dataframe.pickle.gzip', compression='gzip')

# %%
intervals.head()
# Out:
#             sample chromosome    start     stop   hmm_state      chrom_id  \
# 100999  BSP-OR-202          1        1  2820551          N2  BSP-OR-202-1
# 101000  BSP-OR-202          1  2820551  2820595  transition  BSP-OR-202-1
# 101001  BSP-OR-202          1  2820595  2821506      CB4856  BSP-OR-202-1
# 101002  BSP-OR-202          1  2821506  2821610  transition  BSP-OR-202-1
# 101003  BSP-OR-202          1  2821610  8506388          N2  BSP-OR-202-1
#
#          length  marker_counts
# 100999  2820551           7310
# 101000       44              2
# 101001      912             27
# 101002      104              2
# 101003  5684779           4643

# %%
len(intervals)
# Out:
# 326744

# %%
intervals[intervals.chrom_id == 'BSP-OR-001-4'].head(50)
# Out:
#          sample chromosome     start      stop   hmm_state      chrom_id  \
# 111  BSP-OR-001          4         1   1996956      CB4856  BSP-OR-001-4
# 112  BSP-OR-001          4   1996956   1997145  transition  BSP-OR-001-4
# 113  BSP-OR-001          4   1997145   1997566          N2  BSP-OR-001-4
# 114  BSP-OR-001          4   1997566   1997578  transition  BSP-OR-001-4
# 115  BSP-OR-001          4   1997578   2156628      CB4856  BSP-OR-001-4
# 116  BSP-OR-001          4   2156628   2157039  transition  BSP-OR-001-4
# 117  BSP-OR-001          4   2157039   2157113          N2  BSP-OR-001-4
# 118  BSP-OR-001          4   2157113   2157459  transition  BSP-OR-001-4
# 119  BSP-OR-001          4   2157459   2571243      CB4856  BSP-OR-001-4
# 120  BSP-OR-001          4   2571243   2571293  transition  BSP-OR-001-4
# 121  BSP-OR-001          4   2571293   2588635          N2  BSP-OR-001-4
# 122  BSP-OR-001          4   2588635   2588636  transition  BSP-OR-001-4
# 123  BSP-OR-001          4   2588636   2693573      CB4856  BSP-OR-001-4
# 124  BSP-OR-001          4   2693573   2694389  transition  BSP-OR-001-4
# 125  BSP-OR-001          4   2694389   2695998          N2  BSP-OR-001-4
# 126  BSP-OR-001          4   2695998   2696007  transition  BSP-OR-001-4
# 127  BSP-OR-001          4   2696007   3206257      CB4856  BSP-OR-001-4
# 128  BSP-OR-001          4   3206257   3206444  transition  BSP-OR-001-4
